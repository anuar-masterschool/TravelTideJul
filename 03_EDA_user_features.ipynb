# %% [markdown]
# # EDA for the created User Features

# %%
import seaborn as sns

# %%
import pandas as pd
user_features = pd.read_csv('data/user_features.csv')

# %%
user_features
# Out:
#       user_id  Age gender home_country    home_city  married  has_children  \
# 0       94883   54      F          usa  kansas city     True         False
# 1      101486   53      F          usa       tacoma     True          True
# 2      101961   45      F          usa       boston     True         False
# 3      106907   47      F          usa        miami     True          True
# 4      118043   54      F          usa  los angeles    False          True
# ...       ...  ...    ...          ...          ...      ...           ...
# 5777   780167   52      F          usa  los angeles     True          True
# 5778   785186   47      F          usa  little rock     True          True
# 5779   792549   48      F          usa  kansas city    False         False
# 5780   811077   47      F          usa    knoxville     True          True
# 5781   844489   26      M          usa      el paso    False          True
#
#             Age Group  trip_session_ratio  nights_median  hotel_tot_rev  \
# 0     Age Group 50-65            3.666667            1.0         230.00
# 1     Age Group 50-65            3.333333            4.0        2640.00
# 2     Age Group 35-50            1.714286            4.0        3520.00
# 3     Age Group 35-50            1.500000            6.0        2185.20
# 4     Age Group 50-65            2.200000            6.5        6443.45
# ...               ...                 ...            ...            ...
# 5777  Age Group 50-65            2.500000            1.0         220.00
# 5778  Age Group 35-50            4.000000            1.5         475.00
# 5779  Age Group 35-50            2.000000            5.0         180.00
# 5780  Age Group 35-50            8.000000            7.0         994.00
# 5781  Age Group 18-35                 NaN            NaN            NaN
#
#       hotel_avg_rev  hotels_no_bookings  hotel_tot_nights  hotel_avg_nights  \
# 0        115.000000                 2.0               2.0          1.000000
# 1        880.000000                 3.0              11.0          3.666667
# 2        502.857143                 7.0              26.0          3.714286
# 3       1092.600000                 2.0              12.0          6.000000
# 4       1610.862500                 4.0              24.0          6.000000
# ...             ...                 ...               ...               ...
# 5777     220.000000                 1.0               1.0          1.000000
# 5778     237.500000                 2.0               3.0          1.500000
# 5779     180.000000                 1.0               5.0          5.000000
# 5780     994.000000                 1.0               7.0          7.000000
# 5781            NaN                 NaN               NaN               NaN
#
#       flight_no_bookings  flight_avg_seats  flight_avg_rev  flight_tot_rev
# 0                    3.0          1.666667     3489.600000      10468.8000
# 1                    2.0          1.000000      175.871250        351.7425
# 2                    6.0          1.000000      320.705500       1924.2330
# 3                    1.0          1.000000      165.510000        165.5100
# 4                    3.0          2.000000     1708.853333       5126.5600
# ...                  ...               ...             ...             ...
# 5777                 2.0          1.500000      798.591000       1597.1820
# 5778                 2.0          1.000000      176.675000        353.3500
# 5779                 4.0          1.000000      259.792500       1039.1700
# 5780                 1.0          1.000000      579.790000        579.7900
# 5781                 NaN               NaN             NaN             NaN
#
# [5782 rows x 19 columns]

# %%
user_features["total_revenue"] =  user_features["hotel_tot_rev"] + user_features[("flight_tot_rev")]

# %% [markdown]
# # Revenue Analysis

# %%
user_features["trip_session_ratio"].value_counts()
# Out:
# trip_session_ratio
# 2.000000     904
# 2.666667     505
# 4.000000     462
# 3.000000     414
# 1.600000     282
# 2.333333     276
# 1.500000     224
# 3.500000     222
# 1.000000     207
# 2.500000     192
# 1.750000     182
# 8.000000     168
# 1.333333     149
# 1.666667     141
# 5.000000     128
# 2.250000     127
# 6.000000     107
# 1.800000     102
# 7.000000      99
# 4.500000      95
# 1.250000      51
# 1.400000      51
# 1.200000      26
# 3.333333      22
# 1.166667      22
# 9.000000      22
# 2.200000      18
# 1.142857      16
# 1.285714      12
# 3.666667       7
# 2.750000       7
# 10.000000      7
# 1.833333       6
# 1.428571       6
# 1.571429       4
# 1.714286       2
# 2.400000       2
# 5.500000       2
# 1.125000       2
# 2.600000       1
# 1.444444       1
# 1.625000       1
# Name: count, dtype: int64

# %%
user_features["trip_session_ratio"].hist()
# Out:
# <Axes: >

# %%
user_features["total_revenue"].hist()
# Out:
# <Axes: >

# %%
sns.scatterplot(user_features,x="trip_session_ratio", y="total_revenue")
# Out:
# <Axes: xlabel='trip_session_ratio', ylabel='total_revenue'>

# %%
sns.boxplot(user_features,x="trip_session_ratio", y="hotel_tot_rev")
# Out:
# <Axes: xlabel='trip_session_ratio', ylabel='hotel_tot_rev'>

# %%
sns.boxplot(user_features,x="trip_session_ratio", y="flight_tot_rev")
# Out:
# <Axes: xlabel='trip_session_ratio', ylabel='flight_tot_rev'>

# %% [markdown]
# # Age Groups

# %%
age_order = ["Age Group 18-35", "Age Group 35-50", "Age Group 50-65", "Age Group 65+"]

# %%
sns.barplot(user_features,x="Age Group", y="hotel_tot_rev", order=age_order)
# Out:
# <Axes: xlabel='Age Group', ylabel='hotel_tot_rev'>

# %%
sns.barplot(user_features,x="Age Group", y="flight_tot_rev", order=age_order)
# Out:
# <Axes: xlabel='Age Group', ylabel='flight_tot_rev'>

# %%
sns.barplot(user_features,x="Age Group", y="hotels_no_bookings", order=age_order)
# Out:
# <Axes: xlabel='Age Group', ylabel='hotels_no_bookings'>

# %%
sns.barplot(user_features,x="Age Group", y="flight_no_bookings", order=age_order)
# Out:
# <Axes: xlabel='Age Group', ylabel='flight_no_bookings'>

# %%
sns.barplot(user_features, x="Age Group", y="flight_avg_seats", order=age_order)
# Out:
# <Axes: xlabel='Age Group', ylabel='flight_avg_seats'>

# %%
sns.boxplot(user_features, x="Age", y="flight_avg_seats")
# Out:
# <Axes: xlabel='Age', ylabel='flight_avg_seats'>

# %%
sns.countplot(user_features,x="Age Group", order=age_order)
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
sns.barplot(user_features, x="gender", y="total_revenue")
# Out:
# <Axes: xlabel='gender', ylabel='total_revenue'>

# %%
sns.countplot(user_features, x="Age Group", order=age_order, hue="gender")
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
user_features.columns
# Out:
# Index(['user_id', 'Age', 'gender', 'home_country', 'home_city', 'married',
#        'has_children', 'Age Group', 'trip_session_ratio', 'nights_median',
#        'hotel_tot_rev', 'hotel_avg_rev', 'hotels_no_bookings',
#        'hotel_tot_nights', 'hotel_avg_nights', 'flight_no_bookings',
#        'flight_avg_seats', 'flight_avg_rev', 'flight_tot_rev',
#        'total_revenue'],
#       dtype='str')

# %%
import plotly.express as px

# %%
fig = px.scatter(user_features, x="flight_avg_rev", y="hotel_avg_rev", color="gender", opacity=0.1)
fig.show()
#fig.write_html("scatter_plot.html")

# %%
sns.scatterplot(user_features.query("Age < 20"), x="flight_avg_rev", y="hotel_avg_rev", alpha=0.5)
# Out:
# <Axes: xlabel='flight_avg_rev', ylabel='hotel_avg_rev'>

# %%
sns.histplot(user_features,x = "Age")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>
