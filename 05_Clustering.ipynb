# %% [markdown]
# # Clustering from the leftovers

# %%
import pandas as pd

users = pd.read_csv("data/groups/leftovers.csv")

# %%
users
# Out:
#       user_id  Age gender home_country    home_city  married  has_children  \
# 0      101486   53      F          usa       tacoma     True          True
# 1      101961   45      F          usa       boston     True         False
# 2      106907   47      F          usa        miami     True          True
# 3      153982   47      F       canada      toronto    False          True
# 4      167852   20      F          usa        tampa    False         False
# ...       ...  ...    ...          ...          ...      ...           ...
# 5069   780167   52      F          usa  los angeles     True          True
# 5070   785186   47      F          usa  little rock     True          True
# 5071   792549   48      F          usa  kansas city    False         False
# 5072   811077   47      F          usa    knoxville     True          True
# 5073   844489   26      M          usa      el paso    False          True
#
#             Age Group  trip_session_ratio  nights_median  ...  \
# 0     Age Group 50-65            3.333333            4.0  ...
# 1     Age Group 35-50            1.714286            4.0  ...
# 2     Age Group 35-50            1.500000            6.0  ...
# 3     Age Group 35-50            2.250000            2.5  ...
# 4     Age Group 18-35                 NaN            NaN  ...
# ...               ...                 ...            ...  ...
# 5069  Age Group 50-65            2.500000            1.0  ...
# 5070  Age Group 35-50            4.000000            1.5  ...
# 5071  Age Group 35-50            2.000000            5.0  ...
# 5072  Age Group 35-50            8.000000            7.0  ...
# 5073  Age Group 18-35                 NaN            NaN  ...
#
#       hotels_no_bookings  hotel_tot_nights  hotel_avg_nights  \
# 0                    3.0              11.0          3.666667
# 1                    7.0              26.0          3.714286
# 2                    2.0              12.0          6.000000
# 3                    4.0              16.0          4.000000
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 5069                 1.0               1.0          1.000000
# 5070                 2.0               3.0          1.500000
# 5071                 1.0               5.0          5.000000
# 5072                 1.0               7.0          7.000000
# 5073                 NaN               NaN               NaN
#
#       flight_no_bookings  flight_avg_seats  flight_avg_rev  flight_tot_rev  \
# 0                    2.0               1.0       175.87125        351.7425
# 1                    6.0               1.0       320.70550       1924.2330
# 2                    1.0               1.0       165.51000        165.5100
# 3                    4.0               1.0       197.49000        789.9600
# 4                    NaN               NaN             NaN             NaN
# ...                  ...               ...             ...             ...
# 5069                 2.0               1.5       798.59100       1597.1820
# 5070                 2.0               1.0       176.67500        353.3500
# 5071                 4.0               1.0       259.79250       1039.1700
# 5072                 1.0               1.0       579.79000        579.7900
# 5073                 NaN               NaN             NaN             NaN
#
#       hotel_avg_rev_per_night  hotel_avg_rev_per_night_delta  \
# 0                  240.000000                      28.199211
# 1                  135.384615                     -76.416173
# 2                  182.100000                     -29.700789
# 3                  168.000000                     -43.800789
# 4                         NaN                            NaN
# ...                       ...                            ...
# 5069               220.000000                       8.199211
# 5070               158.333333                     -53.467455
# 5071                36.000000                    -175.800789
# 5072               142.000000                     -69.800789
# 5073                      NaN                            NaN
#
#       total_avg_revenue
# 0           1055.871250
# 1            823.562643
# 2           1258.110000
# 3            869.490000
# 4                   NaN
# ...                 ...
# 5069        1018.591000
# 5070         414.175000
# 5071         439.792500
# 5072        1573.790000
# 5073                NaN
#
# [5074 rows x 22 columns]

# %% [markdown]
# # Preprocessing

# %%
df_preprocessed = users.copy()

# %% [markdown]
# ## Drop
# - user_id
# - Age Group
# - home_city

# %%
df_preprocessed.drop(["user_id", "Age Group", "home_city"], axis=1, inplace=True)

# %%
df_preprocessed.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5074 entries, 0 to 5073
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            5074 non-null   int64
#  1   gender                         5074 non-null   str
#  2   home_country                   5074 non-null   str
#  3   married                        5074 non-null   bool
#  4   has_children                   5074 non-null   bool
#  5   trip_session_ratio             4636 non-null   float64
#  6   nights_median                  4552 non-null   float64
#  7   hotel_tot_rev                  4552 non-null   float64
#  8   hotel_avg_rev                  4552 non-null   float64
#  9   hotels_no_bookings             4552 non-null   float64
#  10  hotel_tot_nights               4552 non-null   float64
#  11  hotel_avg_nights               4552 non-null   float64
#  12  flight_no_bookings             4326 non-null   float64
#  13  flight_avg_seats               4326 non-null   float64
#  14  flight_avg_rev                 4326 non-null   float64
#  15  flight_tot_rev                 4326 non-null   float64
#  16  hotel_avg_rev_per_night        4552 non-null   float64
#  17  hotel_avg_rev_per_night_delta  4552 non-null   float64
#  18  total_avg_revenue              4242 non-null   float64
# dtypes: bool(2), float64(14), int64(1), str(2)
# memory usage: 683.9 KB
